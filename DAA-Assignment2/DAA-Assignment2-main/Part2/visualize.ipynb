# %%
import matplotlib.pyplot as plt

x_values_input = []
y_values_input = []

# open the file in read mode
with open('input.txt', 'r') as file:
    # skip the first line (header)
    next(file)
    next(file)
    # iterate over each line in the file
    for line in file:
        # split the line into two values using whitespace as the separator
        x, y = line.strip().split(' ')
        # append the values to the respective lists as floats
        x_values_input.append(float(x))
        y_values_input.append(float(y))

# print the x and y values
print(x_values_input)
print(y_values_input)

# Plot the points
plt.plot(x_values_input, y_values_input, 'o')


# create empty lists to store x and y values
x_values = []
y_values = []

# open the file in read mode
with open('output1.txt', 'r') as file:
    # iterate over each line in the file
    for line in file:
        # split the line into two values using comma as the separator
        x, y = line.strip().split(' ')
        # append the values to the respective lists as floats
        x_values.append(float(x))
        y_values.append(float(y))

# print the x and y values
print(x_values)
print(y_values)


for i in range(len(x_values) - 1):
    plt.plot([x_values[i], x_values[i+1]], [y_values[i], y_values[i+1]])
    

# Add labels and title
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Points and Line Plot')

# Show the plot
plt.show()
# Out:
# [0.0, 1.0]
# [0.0, 1.0]
# [1.0, 0.0]
# [1.0, 0.0]
